# %%
from ravens_route import predict_route_prob
from ravens_route.models_io import get_route_encoder, get_route_features, get_route_encoder, get_route_model
import pandas as pd

# %%
df = pd.read_csv("data/final_matchup_data.csv")

# %%
row = df.iloc[0]
print("Predicted probability (normal):", predict_route_prob(row))
# Out:
# Predicted probability (normal): 0.6605860590934753
